# %%
from pynq import PL
from pynq import Overlay
from pynq import allocate

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
PL.reset()
xadc_stream = Overlay('led_ctl.bit')

# %%
xadc_stream?

# %%
btn     = xadc_stream.axi_gpio_btn
rgb     = xadc_stream.axi_gpio_rgb

# %%
val = btn.read(0)
print(val)

# %%
rgb.write(0,val)
